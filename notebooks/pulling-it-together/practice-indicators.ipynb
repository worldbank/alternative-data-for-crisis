# %% [markdown]
# # Practice
# We are going to calculate summary indicators for the Rio Grande do Sul flood in Brazil. Please obtain:
# 1. Total number of affected population.
# 2. Affected population by administrative level 2. Create a bar plot showing the 5 most affected administrative boundaries.
# 3. Number of hospitals and education institutions affected by the flood.
#
# ```{note}
# Notice that in previous classes and practices, you had downloaded the necessary  input data for solving this practice.
# ```
#
# ```{note}
# Before you start, let's discuss together how to tackle this practice.
# ```
